# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging
import os

# %%
save_dir = "images/"
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# %%
Query = "Lotus"
response = requests.get(f"https://www.google.com/search?q={Query}&sxsrf=APwXEdfeHJryNy0ZpSHbz2LS7ADGZeg25w:1683832774222&source=lnms&tbm=isch&sa=X&ved=2ahUKEwjD-_jy_e3-AhWatlYBHRdPCdwQ_AUoAXoECAEQAw&biw=1366&bih=649&dpr=1")

# %%
response
# Out:
# <Response [200]>

# %%
response.content
# Out:
# b'<!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.0//EN" "http://www.wapforum.org/DTD/xhtml-mobile10.dtd"><html xmlns="http://www.w3.org/1999/xhtml" lang="en-IN"><head><meta content="application/xhtml+xml; charset=UTF-8" http-equiv="Content-Type"/><meta content="no-cache" name="Cache-Control"/><title>Lotus - Google Search</title><style>a{text-decoration:none;color:inherit}a:hover{text-decoration:underline}a img{border:0}body{font-family:arial,sans-serif;padding:8px;margin:0 auto;max-width:700px;min-width:240px;}.FbhRzb{border-left:thin solid #dadce0;border-right:thin solid #dadce0;border-top:thin solid #dadce0;height:40px;overflow:hidden}.n692Zd{margin-bottom:10px}.cvifge{height:40px;border-spacing:0}.QvGUP{height:40px;padding:0 8px 0 8px;vertical-align:top}.O4cRJf{height:40px;width:100%;padding:0;padding-right:16px}.O1ePr{height:40px;padding:0;vertical-align:top}.kgJEQe{height:36px;width:98px;vertical-align:top;margin-top:4px}.lXLRf{vertical-align:top}.MhzMZd{border:0;vertica
# ...

# %%
bs(response.content,"html.parser")
# Out:
# <!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.0//EN" "http://www.wapforum.org/DTD/xhtml-mobile10.dtd">
# ...

# %%
soup = bs(response.content,"html.parser")

# %%
soup.find_all("img")
# Out:
# [<img alt="Google" class="kgJEQe" src="/images/branding/searchlogo/1x/googlelogo_desk_heirloom_color_150x55dp.gif"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS_4t-c_VSEEgwsINTgh5QBdUKWddboUHKK_9zppF524ueBrJhJKTENKgK6qoY&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRbrd608ur31-17-ng4S0IHIMovArkUZr_fooTK17pCLp3AtApOw8hEdrrBcQ&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQHpm4a19dWQGrepsADy_I-rVf41qen0_iugYS3vujfny5oAqyRt6VpGUcIag&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ_W5iVs1XQYULezHH0fDMyygM3ILNSHKtmSGLxREVICdRZJEaAa7rsEJBosMQ&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRPKdqItfHCLJKz5LkrckydKojfJGA83nQjFloZt0SEYxCk74eWuVQHsnnC8Q&amp;s"/>,
# ...

# %%
image_tags = soup.find_all("img")

# %%
del image_tags[0]

# %%
len(image_tags)
# Out:
# 20

# %%
image_data_mango = []
for i in image_tags:
    image_url = i["src"]
    image_data = requests.get(image_url).content
    mydict = {"Index" : image_url, "image": image_data}
    image_data_mango.append(mydict)
    with open(os.path.join(save_dir,f"{Query}_{image_tags.index(i)}.jpg"), "wb") as f:
                           f.write(image_data)
